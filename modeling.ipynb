# %% [markdown]
# # Modeling

# %%
# frst lets clean some of our data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

# %%
df_accident = pd.read_csv('./data/accident.csv')
df_accident.columns = df_accident.columns.str.lower()

# %%
df_accident.head()
# Out:
#    state statename  st_case  ve_total  ve_forms  pvh_invl  peds  persons  \
# 0      1   Alabama    10001         1         1         0     0        4
# 1      1   Alabama    10002         4         4         0     0        6
# 2      1   Alabama    10003         2         2         0     0        2
# 3      1   Alabama    10004         1         1         0     0        5
# 4      1   Alabama    10005         1         1         0     0        1
#
#    permvit  pernotmvit  ...  arr_hour                    arr_hourname  \
# 0        4           0  ...         3                   3:00am-3:59am
# 1        6           0  ...        17                   5:00pm-5:59pm
# 2        2           0  ...        15                   3:00pm-3:59pm
# 3        5           0  ...        99  Unknown EMS Scene Arrival Hour
# 4        1           0  ...         0                   0:00am-0:59am
#
#    arr_min                        arr_minname  hosp_hr  \
# ...

# %%
df_accident.isna().sum()
# Out:
# state          0
# statename      0
# st_case        0
# ve_total       0
# ve_forms       0
#               ..
# hosp_hrname    0
# hosp_mn        0
# hosp_mnname    0
# fatals         0
# drunk_dr       0
# Length: 81, dtype: int64

# %%
df_accident.isnull().sum()
# Out:
# state          0
# statename      0
# st_case        0
# ve_total       0
# ve_forms       0
#               ..
# hosp_hrname    0
# hosp_mn        0
# hosp_mnname    0
# fatals         0
# drunk_dr       0
# Length: 81, dtype: int64

# %%
df_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35766 entries, 0 to 35765
# Data columns (total 81 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         35766 non-null  int64
#  1   statename     35766 non-null  object
#  2   st_case       35766 non-null  int64
#  3   ve_total      35766 non-null  int64
#  4   ve_forms      35766 non-null  int64
#  5   pvh_invl      35766 non-null  int64
#  6   peds          35766 non-null  int64
#  7   persons       35766 non-null  int64
#  8   permvit       35766 non-null  int64
#  9   pernotmvit    35766 non-null  int64
#  10  county        35766 non-null  int64
#  11  countyname    35766 non-null  object
#  12  city          35766 non-null  int64
#  13  cityname      35766 non-null  object
#  14  day           35766 non-null  int64
#  15  dayname       35766 non-null  int64
#  16  month         35766 non-null  int64
#  17  monthname     35766 non-null  object
# ...

# %%
df_accident.drop(columns='tway_id2', inplace=True)

# %%
df_accident.head()
# Out:
#    state statename  st_case  ve_total  ve_forms  pvh_invl  peds  persons  \
# 0      1   Alabama    10001         1         1         0     0        4
# 1      1   Alabama    10002         4         4         0     0        6
# 2      1   Alabama    10003         2         2         0     0        2
# 3      1   Alabama    10004         1         1         0     0        5
# 4      1   Alabama    10005         1         1         0     0        1
#
#    permvit  pernotmvit  ...  arr_hour                    arr_hourname  \
# 0        4           0  ...         3                   3:00am-3:59am
# 1        6           0  ...        17                   5:00pm-5:59pm
# 2        2           0  ...        15                   3:00pm-3:59pm
# 3        5           0  ...        99  Unknown EMS Scene Arrival Hour
# 4        1           0  ...         0                   0:00am-0:59am
#
#    arr_min                        arr_minname  hosp_hr  \
# ...

# %%
df_accident[['county', 'city']]
# Out:
#        county  city
# 0          51     0
# 1          73   350
# 2         117     0
# 3          15     0
# 4          37     0
# ...       ...   ...
# 35761      21     0
# 35762      23     0
# 35763      13     0
# 35764      21   100
# 35765      31     0
#
# [35766 rows x 2 columns]

# %%
features = ['drunk_dr', 've_total', 'persons']
X = df_accident[features]

y = df_accident['fatals']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Train score
lr.score(X_train,y_train)
# Out:
# 0.09476415384790493

# %% [markdown]
# # Now for the real data cleaning

# %%
df_accident_new = df_accident.drop(columns = ['arr_hourname', 'arr_minname',] )
